# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## Fundamentals of machine learning

# %% [markdown]
# ### Generalization: The goal of machine learning

# %% [markdown]
# #### Underfitting and overfitting

# %% [markdown]
# ##### Noisy training data

# %% [markdown]
# ##### Ambiguous features

# %% [markdown]
# ##### Rare features and spurious correlations

# %%
from keras.datasets import mnist
import numpy as np

(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

train_images_with_noise_channels = np.concatenate(
    [train_images, np.random.random((len(train_images), 784))], axis=1
)

train_images_with_zeros_channels = np.concatenate(
    [train_images, np.zeros((len(train_images), 784))], axis=1
)

# %%
import keras
from keras import layers

def get_model():
    model = keras.Sequential(
        [
            layers.Dense(512, activation="relu"),
            layers.Dense(10, activation="softmax"),
        ]
    )
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

model = get_model()
history_noise = model.fit(
    train_images_with_noise_channels,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
)

model = get_model()
history_zeros = model.fit(
    train_images_with_zeros_channels,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8692 - loss: 0.4357 - val_accuracy: 0.9197 - val_loss: 0.2866
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9319 - loss: 0.2285 - val_accuracy: 0.9418 - val_loss: 0.2029
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9537 - loss: 0.1567 - val_accuracy: 0.9383 - val_loss: 0.2012
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9682 - loss: 0.1086 - val_accuracy: 0.9567 - val_loss: 0.1522
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9759 - loss: 0.0801 - val_accuracy: 0.9586 - val_loss: 0.1421
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9836 - loss: 0.0569 - val_accuracy: 0.9566 - val_loss: 0.1468
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9890 - loss: 0.0398 - val_accuracy: 0.9521 - val_loss: 0.1670
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9917 - loss: 0.0302 - val_accuracy: 0.9626 - val_loss: 0.1342
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9958 - loss: 0.0193 - val_accuracy: 0.9653 - val_loss: 0.1295
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9982 - loss: 0.0112 - val_accuracy: 0.9678 - val_loss: 0.1230
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9165 - loss: 0.2948 - val_accuracy: 0.9521 - val_loss: 0.1610
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9639 - loss: 0.1249 - val_accuracy: 0.9675 - val_loss: 0.1067
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9772 - loss: 0.0789 - val_accuracy: 0.9693 - val_loss: 0.0984
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9839 - loss: 0.0567 - val_accuracy: 0.9707 - val_loss: 0.0931
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9876 - loss: 0.0421 - val_accuracy: 0.9756 - val_loss: 0.0820
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9920 - loss: 0.0303 - val_accuracy: 0.9757 - val_loss: 0.0773
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9946 - loss: 0.0220 - val_accuracy: 0.9770 - val_loss: 0.0775
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9958 - loss: 0.0170 - val_accuracy: 0.9766 - val_loss: 0.0805
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9967 - loss: 0.0138 - val_accuracy: 0.9787 - val_loss: 0.0733
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9976 - loss: 0.0109 - val_accuracy: 0.9789 - val_loss: 0.0745

# %%
import matplotlib.pyplot as plt

val_acc_noise = history_noise.history["val_accuracy"]
val_acc_zeros = history_zeros.history["val_accuracy"]
epochs = range(1, 11)
plt.plot(
    epochs,
    val_acc_noise,
    "b-",
    label="Validation accuracy with noise channels",
)
plt.plot(
    epochs,
    val_acc_zeros,
    "r--",
    label="Validation accuracy with zeros channels",
)
plt.title("Effect of noise channels on validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# #### The nature of generalization in deep learning

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

random_train_labels = train_labels[:]
np.random.shuffle(random_train_labels)

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images,
    random_train_labels,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1030 - loss: 2.3152 - val_accuracy: 0.1005 - val_loss: 2.3052
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.
100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8060 - loss: 0.6046 - val_accuracy: 0.0992 - val_loss: 5.7683
# Epoch 73/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8102 - loss: 0.5930 - val_accuracy: 0.0989 - val_loss: 5.7920
# Epoch 74/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8117 - loss: 0.5849 - val_accuracy: 0.1015 - val_loss: 5.9175
# Epoch 75/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8175 - loss: 0.5724 - val_accuracy: 0.1010 - val_loss: 5.9523
# Epoch 76/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8211 - loss: 0.5610 - val_accuracy: 0.1002 - val_loss: 5.9905
# Epoch 77/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8253 - loss: 0.5505 - val_accuracy: 0.0958 - val_loss: 6.0970
# Epoch 78/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8285 - loss: 0.5379 - val_accuracy: 0.0972 - val_loss: 6.1774
# Epoch 79/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8310 - loss: 0.5311 - val_accuracy: 0.0998 - val_loss: 6.1782
# Epoch 80/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8332 - loss: 0.5215 - val_accuracy: 0.0983 - val_loss: 6.2345
# Epoch 81/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8361 - loss: 0.5113 - val_accuracy: 0.0976 - val_loss: 6.3343
# Epoch 82/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8388 - loss: 0.5006 - val_accuracy: 0.0967 - val_loss: 6.3989
# Epoch 83/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8421 - loss: 0.4927 - val_accuracy: 0.0962 - val_loss: 6.4347
# Epoch 84/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8467 - loss: 0.4834 - val_accuracy: 0.0979 - val_loss: 6.4838
# Epoch 85/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8501 - loss: 0.4740 - val_accuracy: 0.0988 - val_loss: 6.5502
# Epoch 86/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8529 - loss: 0.4678 - val_accuracy: 0.1004 - val_loss: 6.6678
# Epoch 87/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8559 - loss: 0.4563 - val_accuracy: 0.0991 - val_loss: 6.6967
# Epoch 88/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8588 - loss: 0.4476 - val_accuracy: 0.0985 - val_loss: 6.7741
# Epoch 89/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8605 - loss: 0.4398 - val_accuracy: 0.0980 - val_loss: 6.7787
# Epoch 90/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8659 - loss: 0.4322 - val_accuracy: 0.0987 - val_loss: 6.8497
# Epoch 91/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8673 - loss: 0.4240 - val_accuracy: 0.0967 - val_loss: 6.9142
# Epoch 92/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8678 - loss: 0.4169 - val_accuracy: 0.0991 - val_loss: 6.9531
# Epoch 93/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8709 - loss: 0.4107 - val_accuracy: 0.0993 - val_loss: 6.9712
# Epoch 94/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8743 - loss: 0.4024 - val_accuracy: 0.0989 - val_loss: 7.0321
# Epoch 95/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8762 - loss: 0.3959 - val_accuracy: 0.0993 - val_loss: 7.1161
# Epoch 96/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8784 - loss: 0.3882 - val_accuracy: 0.1030 - val_loss: 7.1643
# Epoch 97/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8807 - loss: 0.3810 - val_accuracy: 0.1011 - val_loss: 7.2103
# Epoch 98/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8833 - loss: 0.3741 - val_accuracy: 0.1002 - val_loss: 7.2566
# Epoch 99/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8872 - loss: 0.3658 - val_accuracy: 0.1002 - val_loss: 7.3878
# Epoch 100/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8871 - loss: 0.3623 - val_accuracy: 0.1018 - val_loss: 7.3715

# %% [markdown]
# ##### The manifold hypothesis

# %% [markdown]
# ##### Interpolation as a source of generalization

# %% [markdown]
# ##### Why deep learning works

# %% [markdown]
# ##### Training data is paramount

# %% [markdown]
# ### Evaluating machine-learning models

# %% [markdown]
# #### Training, validation, and test sets

# %% [markdown]
# ##### Simple hold-out validation

# %% [markdown]
# ##### K-fold validation

# %% [markdown]
# ##### Iterated K-fold validation with shuffling

# %% [markdown]
# #### Beating a common-sense baseline

# %% [markdown]
# #### Things to keep in mind about model evaluation

# %% [markdown]
# ### Improving model fit

# %% [markdown]
# #### Tuning key gradient descent parameters

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 273us/step - accuracy: 0.9294 - loss: 0.2561 - val_accuracy: 0.9314 - val_loss: 0.2621

# %%
import matplotlib.pyplot as plt

val_loss = history_small_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label="Validation loss")
plt.title("Validation loss for a model with insufficient capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(128, activation="relu"),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
history_large_model = model.fit(
    train_images,
    train_labels,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9021 - loss: 0.3418 - val_accuracy: 0.9533 - val_loss: 0.1644
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 0.9574 - loss: 0.1402 - val_accuracy: 0.9599 - val_loss: 0.1322
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.9710 - loss: 0.0962 - val_accuracy: 0.9661 - val_loss: 0.1078
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - accuracy: 0.9778 - loss: 0.0727 - val_accuracy: 0.9722 - val_loss: 0.0940
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.9822 - loss: 0.0569 - val_accuracy: 0.9697 - val_loss: 0.0997
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.9863 - loss: 0.0451 - val_accuracy: 0.9764 - val_loss: 0.0846
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - accuracy: 0.9886 - loss: 0.0360 - val_accuracy: 0.9728 - val_loss: 0.0958
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.9905 - loss: 0.0299 - val_accuracy: 0.9730 - val_loss: 0.1015
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - accuracy: 0.9926 - loss: 0.0241 - val_accuracy: 0.9735 - val_loss: 0.1023
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - accuracy: 0.9938 - loss: 0.0203 - val_accuracy: 0.9745 - val_loss: 0.0985
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.9953 - loss: 0.0161 - val_accuracy: 0.9740 - val_loss: 0.1105
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - accuracy: 0.9956 - loss: 0.0136 - val_accuracy: 0.9744 - val_loss: 0.1076
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.9962 - loss: 0.0121 - val_accuracy: 0.9775 - val_loss: 0.1035
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - accuracy: 0.9972 - loss: 0.0095 - val_accuracy: 0.9778 - val_loss: 0.1075
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.9976 - loss: 0.0083 - val_accuracy: 0.9758 - val_loss: 0.1127
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.9980 - loss: 0.0068 - val_accuracy: 0.9776 - val_loss: 0.1111
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - accuracy: 0.9984 - loss: 0.0056 - val_accuracy: 0.9772 - val_loss: 0.1182
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9784 - val_loss: 0.1221
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9985 - loss: 0.0046 - val_accuracy: 0.9777 - val_loss: 0.1202
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9992 - loss: 0.0031 - val_accuracy: 0.9787 - val_loss: 0.1182

# %%
val_loss = history_large_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label="Validation loss")
plt.title("Validation loss for a model with appropriate capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(2048, activation="relu"),
        layers.Dense(2048, activation="relu"),
        layers.Dense(2048, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
history_very_large_model = model.fit(
    train_images,
    train_labels,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9268 - loss: 0.2580 - val_accuracy: 0.9613 - val_loss: 0.1311
# Epoch 2/20
#   77/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9724 - loss: 0.0823
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 14
#       1 model = keras.Sequential(
#       2     [
#       3         layers.Dense(2048, activation="relu"),
#    (...)
#       7     ]
#       8 )
#       9 model.compile(
#      10     optimizer="rmsprop",
#      11     loss="sparse_categorical_crossentropy",
#      12     metrics=["accuracy"],
#      13 )
# ---> 14 history_very_large_model = model.fit(
#      15     train_images,
#      16     train_labels,
#      17     epochs=20,
#      18     batch_size=32,
#      19     validation_split=0.2,
#      20 )
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/keras/src/backend/jax/trainer.py:450, in JAXTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     441     state = self._get_jax_state(
#     442         trainable_variables=True,
#     443         non_trainable_variables=True,
#    (...)
#     446         purge_model_variables=True,
#     447     )
#     448     self._jax_state_synced = False
# --> 450 logs, state = self.train_function(state, iterator)
#     451 (
#     452     trainable_variables,
#     453     non_trainable_variables,
#     454     optimizer_variables,
#     455     metrics_variables,
#     456 ) = state
#     458 # Setting _jax_state enables callbacks to force a state
#     459 # sync if they need to.
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/keras/src/backend/jax/trainer.py:257, in JAXTrainer._make_function.<locals>.iterator_step(state, iterator)
#     256 def iterator_step(state, iterator):
# --> 257     return step_function(state, next(iterator))
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/keras/src/backend/jax/trainer.py:1038, in JAXEpochIterator._prefetch_numpy_iterator(self, numpy_iterator)
#    1036 while queue:
#    1037     yield queue.popleft()
# -> 1038     enqueue(1)
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/keras/src/backend/jax/trainer.py:1032, in JAXEpochIterator._prefetch_numpy_iterator.<locals>.enqueue(n)
#    1031 def enqueue(n=2):
# -> 1032     for data in itertools.islice(numpy_iterator, n):
#    1033         queue.append(_distribute_data(data))
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:344, in ArrayDataAdapter._get_iterator(self, slice_and_convert_fn, inputs)
#     339     indices = slice(start, stop)
#     341 slice_indices_and_convert_fn = functools.partial(
#     342     slice_and_convert_fn, indices=indices
#     343 )
# --> 344 yield tree.map_structure(
#     345     slice_indices_and_convert_fn, inputs, none_is_leaf=False
#     346 )
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/keras/src/tree/tree_api.py:200, in map_structure(func, none_is_leaf, *structures)
#     167 @keras_export("keras.tree.map_structure")
#     168 def map_structure(func, *structures, none_is_leaf=True):
#     169     """Maps `func` through given structures.
#     170
#     171     Examples:
#    (...)
#     198             `assert_same_structure`.
#     199     """
# --> 200     return tree_impl.map_structure(func, *structures, none_is_leaf=none_is_leaf)
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/keras/src/tree/optree_impl.py:111, in map_structure(func, none_is_leaf, *structures)
#     107     return func(*args)
#     109 map_func = func_with_check if len(structures) > 1 else func
# --> 111 return optree.tree_map(
#     112     map_func, *structures, none_is_leaf=none_is_leaf, namespace="keras"
#     113 )
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/optree/ops.py:782, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     780 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     781 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 782 return treespec.unflatten(map(func, *flat_args))
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:253, in ArrayDataAdapter.get_jax_iterator.<locals>.slice_and_convert_to_jax(sliceable, indices)
#     251 def slice_and_convert_to_jax(sliceable, indices=None):
#     252     x = sliceable[indices]
# --> 253     x = sliceable.convert_to_jax_compatible(x)
#     254     return x
#
# File ~/gitrepos/deep-learning-with-python-notebooks/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_slicing.py:91, in Sliceable.convert_to_jax_compatible(cls, x)
#      79     """Convert a tensor to something compatible with `tf.data.Dataset`.
#      80
#      81     This can be a NumPy array, `tf.Tensor` or any other type of tensor that
#    (...)
#      87     Returns: converted version tensor.
#      88     """
#      89     return x
# ---> 91 @classmethod
#      92 def convert_to_jax_compatible(cls, x):
#      93     """Convert a tensor to something that the JAX backend can consume.
#      94
#      95     This can be a `JAX` array, `JAXSparse` or a NumPy array.
#    (...)
#     101     Returns: the converted tensor.
#     102     """
#     103     return x
#
# KeyboardInterrupt:

# %%
val_loss = history_very_large_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label="Validation loss")
plt.title("Validation loss for a model with too much capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 val_loss = history_very_large_model.history["val_loss"]
#       2 epochs = range(1, 21)
#       3 plt.plot(epochs, val_loss, "b-", label="Validation loss")
#
# NameError: name 'history_very_large_model' is not defined

# %% [markdown]
# ### Improving generalization

# %% [markdown]
# #### Dataset curation

# %% [markdown]
# #### Feature engineering

# %% [markdown]
# #### Using early stopping

# %% [markdown]
# #### Regularizing your model

# %% [markdown]
# ##### Reducing the network's size

# %%
from keras.datasets import imdb

(train_data, train_labels), _ = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.0
    return results

train_data = vectorize_sequences(train_data)

model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_original = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 12s 1us/step
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9819 - loss: 0.2566 - val_accuracy: 0.8714 - val_loss: 0.4399

# %%
original_val_loss = history_original.history["val_loss"]
smaller_model_val_loss = history_smaller_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    smaller_model_val_loss,
    "b-",
    label="Validation loss of smaller model",
)
plt.title("Original model vs. smaller model (IMDB review classification)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(512, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_larger_model = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.7163 - loss: 0.5645 - val_accuracy: 0.8383 - val_loss: 0.3876
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8750 - loss: 0.3163 - val_accuracy: 0.8849 - val_loss: 0.2862
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9103 - loss: 0.2284 - val_accuracy: 0.8593 - val_loss: 0.3435
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9287 - loss: 0.1851 - val_accuracy: 0.8907 - val_loss: 0.2771
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9407 - loss: 0.1521 - val_accuracy: 0.8784 - val_loss: 0.3132
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9637 - loss: 0.1022 - val_accuracy: 0.8752 - val_loss: 0.3651
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9756 - loss: 0.0720 - val_accuracy: 0.8843 - val_loss: 0.3687
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9793 - loss: 0.0675 - val_accuracy: 0.8815 - val_loss: 0.3907
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9816 - loss: 0.0697 - val_accuracy: 0.8806 - val_loss: 0.3439
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9990 - loss: 0.0100 - val_accuracy: 0.8809 - val_loss: 0.4559
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9909 - loss: 0.0471 - val_accuracy: 0.8563 - val_loss: 0.4877
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9994 - loss: 0.0080 - val_accuracy: 0.8848 - val_loss: 0.4727
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8834 - val_loss: 0.5501
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9823 - loss: 0.0978 - val_accuracy: 0.8798 - val_loss: 0.4338
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8823 - val_loss: 0.4935
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8830 - val_loss: 0.5681
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 7.9517e-04 - val_accuracy: 0.8825 - val_loss: 0.6147
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 4.8872e-04 - val_accuracy: 0.8821 - val_loss: 0.6537
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 3.2888e-04 - val_accuracy: 0.8833 - val_loss: 0.6779
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 2.5214e-04 - val_accuracy: 0.8818 - val_loss: 0.6961

# %%
original_val_loss = history_original.history["val_loss"]
larger_model_val_loss = history_larger_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    larger_model_val_loss,
    "b-",
    label="Validation loss of larger model",
)
plt.title("Original model vs. larger model (IMDB review classification)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %% [markdown]
# ##### Adding weight regularization

# %%
from keras.regularizers import l2

model = keras.Sequential(
    [
        layers.Dense(16, kernel_regularizer=l2(0.002), activation="relu"),
        layers.Dense(16, kernel_regularizer=l2(0.002), activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_l2_reg = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7693 - loss: 0.6044 - val_accuracy: 0.8676 - val_loss: 0.4638
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8947 - loss: 0.3967 - val_accuracy: 0.8718 - val_loss: 0.4079
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9134 - loss: 0.3312 - val_accuracy: 0.8857 - val_loss: 0.3734
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9271 - loss: 0.2942 - val_accuracy: 0.8606 - val_loss: 0.4191
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9327 - loss: 0.2760 - val_accuracy: 0.8887 - val_loss: 0.3609
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9415 - loss: 0.2570 - val_accuracy: 0.8733 - val_loss: 0.3938
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9403 - loss: 0.2532 - val_accuracy: 0.8648 - val_loss: 0.4249
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9469 - loss: 0.2421 - val_accuracy: 0.8791 - val_loss: 0.3847
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9464 - loss: 0.2405 - val_accuracy: 0.8790 - val_loss: 0.3908
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9535 - loss: 0.2293 - val_accuracy: 0.8797 - val_loss: 0.3856
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9513 - loss: 0.2282 - val_accuracy: 0.8772 - val_loss: 0.3995
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9507 - loss: 0.2268 - val_accuracy: 0.8712 - val_loss: 0.4260
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9534 - loss: 0.2210 - val_accuracy: 0.8780 - val_loss: 0.3981
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9553 - loss: 0.2179 - val_accuracy: 0.8560 - val_loss: 0.4760
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9572 - loss: 0.2162 - val_accuracy: 0.8786 - val_loss: 0.4036
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9604 - loss: 0.2076 - val_accuracy: 0.8776 - val_loss: 0.4083
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9613 - loss: 0.2058 - val_accuracy: 0.8721 - val_loss: 0.4310
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9597 - loss: 0.2060 - val_accuracy: 0.8739 - val_loss: 0.4395
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9587 - loss: 0.2059 - val_accuracy: 0.8721 - val_loss: 0.4386
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9564 - loss: 0.2114 - val_accuracy: 0.8731 - val_loss: 0.4373

# %%
original_val_loss = history_original.history["val_loss"]
l2_val_loss = history_l2_reg.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    l2_val_loss,
    "b-",
    label="Validation loss of L2-regularized model",
)
plt.title(
    "Original model vs. L2-regularized model (IMDB review classification)"
)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %%
from keras import regularizers

regularizers.l1(0.001)
regularizers.l1_l2(l1=0.001, l2=0.001)

# %% [markdown]
# ##### Adding dropout

# %%
model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_dropout = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6537 - loss: 0.6214 - val_accuracy: 0.8295 - val_loss: 0.4959
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7751 - loss: 0.4994 - val_accuracy: 0.8597 - val_loss: 0.4097
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8265 - loss: 0.4175 - val_accuracy: 0.8800 - val_loss: 0.3398
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8587 - loss: 0.3558 - val_accuracy: 0.8845 - val_loss: 0.3032
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8831 - loss: 0.3105 - val_accuracy: 0.8903 - val_loss: 0.2812
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9007 - loss: 0.2747 - val_accuracy: 0.8910 - val_loss: 0.2755
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9145 - loss: 0.2418 - val_accuracy: 0.8922 - val_loss: 0.2750
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9270 - loss: 0.2113 - val_accuracy: 0.8896 - val_loss: 0.2867
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9361 - loss: 0.1913 - val_accuracy: 0.8913 - val_loss: 0.2964
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9424 - loss: 0.1681 - val_accuracy: 0.8898 - val_loss: 0.3104
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9472 - loss: 0.1573 - val_accuracy: 0.8871 - val_loss: 0.3343
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9537 - loss: 0.1305 - val_accuracy: 0.8874 - val_loss: 0.3600
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9577 - loss: 0.1199 - val_accuracy: 0.8873 - val_loss: 0.3777
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9579 - loss: 0.1130 - val_accuracy: 0.8857 - val_loss: 0.4045
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9661 - loss: 0.1003 - val_accuracy: 0.8875 - val_loss: 0.4339
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9715 - loss: 0.0943 - val_accuracy: 0.8829 - val_loss: 0.4501
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9717 - loss: 0.0935 - val_accuracy: 0.8862 - val_loss: 0.4688
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9743 - loss: 0.0802 - val_accuracy: 0.8855 - val_loss: 0.4859
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9763 - loss: 0.0787 - val_accuracy: 0.8857 - val_loss: 0.5217
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9758 - loss: 0.0771 - val_accuracy: 0.8860 - val_loss: 0.5444

# %%
original_val_loss = history_original.history["val_loss"]
dropout_val_loss = history_dropout.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    dropout_val_loss,
    "b-",
    label="Validation loss of dropout-regularized model",
)
plt.title(
    "Original model vs. dropout-regularized model (IMDB review classification)"
)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()
